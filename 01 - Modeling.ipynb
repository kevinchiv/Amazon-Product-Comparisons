# %% [markdown]
# # 01 - Modeling

# %% [markdown]
# ## 1. Import Packages <a name="import"></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import gzip
import pickle

# %%
import glob
import os
from collections import defaultdict
import re

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import naive_bayes
from sklearn.model_selection import GridSearchCV

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import re
import string
import nltk
from nltk.stem import WordNetLemmatizer
import gzip

# %%
import spacy

spacy.prefer_gpu()
nlp = spacy.load('en_core_web_sm')

# %%
import gensim

# Uncomment below if running for first time. 
# Setup nltk corpora path and Google Word2Vec location
file_dir = os.path.abspath('.')
folder = 'data'
google_vec_file = os.path.join(file_dir, folder, 'GoogleNews-vectors-negative300.bin')

model = gensim.models.KeyedVectors.load_word2vec_format(google_vec_file, binary=True)

# %% [markdown]
# ## Table of Contents <a name="table"></a>
# 1. [Import Packages](#import)
# 2. [Load Data](#load)
# 3. [Clean Data](#clean)
# 4. [Tokenize](#token)
# 5. [Text Cleaning](#text)
# 6. [Modeling](#model)

# %% [markdown]
# ## 2. Load Data <a name="load"></a>

# %% [markdown]
# The data set can be found at https://s3.amazonaws.com/amazon-reviews-pds/readme.html

# %%
def file_to_df(filepath):  
    """
        Function to parse an Amazon file for a product category.
        Some Amazon files have some characters that prevent delimiters
        from working correctly for the pandas method.
        
        :param filepath: path to the file
        
        :returns df: dataframe version of the file
    """
    
    filename = filepath.split('/')[-1]
    
    print(filename)
    
    with gzip.open(filepath, 'r') as f:
        for row_idx, row in enumerate(f):
            if row_idx == 0:
                row = row.decode('UTF-8')
                row = row.strip().split('\t')
                col_names = row

    print('Number of Rows: ' + str(row_idx))
    
    entry_dict = {name:[None]*row_idx for name in col_names}
    
    with gzip.open(filepath, 'r') as f:
        for row_idx, row in enumerate(f):
            if row_idx == 0:
                continue

            row = row.decode('UTF-8')
            row = row.strip().split('\t')

            for col_idx, name in enumerate(col_names):
                entry_dict[name][row_idx-1] = row[col_idx]
    
    print('Making entry_dict\n')

    df = pd.DataFrame()
    for name in col_names:
        df[name] = entry_dict[name]
        
    entry_dict = None
        
    return df

# %%
product_df = file_to_df('./data/amazon_reviews_us_PC_v1_00.tsv.gz')
# Out:
# amazon_reviews_us_PC_v1_00.tsv.gz
# Number of Rows: 6908554
# Making entry_dict

# %%
product_df.head()
# Out:
#   marketplace customer_id       review_id  product_id product_parent  \
# 0          US    22873041  R3ARRMDEGED8RD  B00KJWQIIC      335625766
# 1          US    30088427   RQ28TSA020Y6J  B013ALA9LA      671157305
# 2          US    20329786   RUXJRZCT6953M  B00PML2GQ8      982036237
# 3          US    14215710   R7EO0UO6BPB71  B001NS0OZ4      576587596
# 4          US    38264512  R39NJY2YJ1JFSV  B00AQMTND2      964759214
#
#                                        product_title product_category  \
# 0  Plemo 14-Inch Laptop Sleeve Case Waterproof Fa...               PC
# 1         TP-Link OnHub AC1900 Wireless Wi-Fi Router               PC
# 2  AmazonBasics USB 3.0 A Male to A Male Cable - ...               PC
# 3  Transcend P8 15-in-1 USB 2.0 Flash Memory Card...               PC
# 4  Aleratec SATA Data Cable 2.0 20in Serial ATA S...               PC
#
#   star_rating helpful_votes total_votes vine verified_purchase  \
# 0           5             0           0    N                 Y
# 1           5            24          31    N                 N
# 2           1             2           2    N                 N
# 3           1             0           0    N                 Y
# 4           5             0           0    N                 Y
#
#                                      review_headline  \
# 0                               Pleasantly surprised
# 1  OnHub is a pretty no nonsense type router that...
# 2     None of them worked.  No functionality at all.
# 3                               just keep searching.
# 4                                         Five Stars
#
#                                          review_body review_date
# 0  I was very surprised at the high quality of th...  2015-08-31
# 1  I am a Google employee and had to chance to us...  2015-08-31
# 2  Bought cables in 3ft, 6ft and 9ft.  NONE of th...  2015-08-31
# 3                               nope, cheap and slow  2015-08-31
# 4           Excellent! Great value and does the job.  2015-08-31

# %% [markdown]
# Return to [Table of Contents](#table)

# %% [markdown]
# ## 3. Clean Data <a name="clean"></a>

# %% [markdown]
# We will remove some columns: <br>
# - 'marketplace' because it is US for all products
# - 'review_id' because it is unique to reviews
# - 'product_id' because 'product_parent' supersedes it

# %%
product_df = product_df.drop(['marketplace', 'review_id', 'product_id'], axis = 1)

# %%
#helpful_votes and total_votes need to be cast as numbers
product_df = product_df.astype({"helpful_votes":np.int64, 
                                "total_votes":np.int64})

# %%
product_df.head()
# Out:
#   customer_id product_parent  \
# 0    22873041      335625766
# 1    30088427      671157305
# 2    20329786      982036237
# 3    14215710      576587596
# 4    38264512      964759214
#
#                                        product_title product_category  \
# 0  Plemo 14-Inch Laptop Sleeve Case Waterproof Fa...               PC
# 1         TP-Link OnHub AC1900 Wireless Wi-Fi Router               PC
# 2  AmazonBasics USB 3.0 A Male to A Male Cable - ...               PC
# 3  Transcend P8 15-in-1 USB 2.0 Flash Memory Card...               PC
# 4  Aleratec SATA Data Cable 2.0 20in Serial ATA S...               PC
#
#   star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0           5              0            0    N                 Y
# 1           5             24           31    N                 N
# 2           1              2            2    N                 N
# 3           1              0            0    N                 Y
# 4           5              0            0    N                 Y
#
#                                      review_headline  \
# 0                               Pleasantly surprised
# 1  OnHub is a pretty no nonsense type router that...
# 2     None of them worked.  No functionality at all.
# 3                               just keep searching.
# 4                                         Five Stars
#
#                                          review_body review_date
# 0  I was very surprised at the high quality of th...  2015-08-31
# 1  I am a Google employee and had to chance to us...  2015-08-31
# 2  Bought cables in 3ft, 6ft and 9ft.  NONE of th...  2015-08-31
# 3                               nope, cheap and slow  2015-08-31
# 4           Excellent! Great value and does the job.  2015-08-31

# %% [markdown]
# In order to improve the results of NLP modeling, we will only focus on select reviews. <br>
# We will only look at reviews with at least 5 helpful upvotes. <br>
# We will also consider reviews written by Vine reviewers since their feedback is usually more accredited.

# %%
helpful_df = product_df[(product_df['helpful_votes'] >= 5) | (product_df['vine'] == 'Y')]

# %%
#find the word laptop in title to focus on laptop products

laptop_brands = ['ASUS', 'Acer', 'Alienware', 'Apple', 'Dell', 'HP', 'Lenovo', 'Samsung']
laptop_types = ['Laptop', 'Chromebook', 'MacBook']
accessory_types = ['Case', 'Adapter', 'Charger']

def find_laptops(title):
    """ Helper function to find only laptops within the Amazon file
        
        :params title: the title of the product
        
        :returns boolean: returns whether the product is a laptop or not
    """
    
    brand = title.split()[0]
    
    #check if the product is within the laptop brands of interest
    if brand in laptop_brands:
        title_words = title.split(' ')
        for word in title_words:
            #if the product is a laptop accessory, we will ignore it
            if word in accessory_types:
                return False
        #otherwise, we will say it is a laptop
        for word in title_words:
            if word in laptop_types:
                return True
    return False


laptop_products_mask = helpful_df['product_title'].apply(find_laptops)

helpful_df = helpful_df[laptop_products_mask]

helpful_df.head()
# Out:
#      customer_id product_parent  \
# 561     33788671      942854828
# 622       108604      218670083
# 996     39145251      774078247
# 1454    25575022      516262603
# 4110    52924529      251834115
#
#                                           product_title product_category  \
# 561   ASUS C201 11.6 Inch Chromebook (Rockchip, 4 GB...               PC
# 622   ASUS K501UX 15-inch Gaming Laptop (Intel Core ...               PC
# 996                           Apple MacBook Pro  Laptop               PC
# 1454                                  Lenovo S41 Laptop               PC
# 4110  HP Chromebook 14 Inch Laptop (NVIDIA Tegra K1,...               PC
#
#      star_rating  helpful_votes  total_votes vine verified_purchase  \
# 561            4              5            5    N                 Y
# 622            1              6            6    N                 Y
# 996            1              7            7    N                 Y
# 1454           4              2            4    Y                 N
# 4110           2              6            7    N                 N
#
#                                review_headline  \
# 561                        Awesome Chromebook!
# 622                       Don't buy this junk.
# 996          Bitter experience. Expensive too!
# 1454        Laptop of The Times - No DVD Drive
# 4110  Will Never, Ever Purchase an HP Product…
#
#                                             review_body review_date
# 561   I was worried that the Rockchip processor woul...  2015-08-31
# 622   Don't buy this laptop, it's good at first but ...  2015-08-31
# 996   I almost forgot about this order, found it acc...  2015-08-31
# 1454  Its a great little laptop. I like the size and...  2015-08-31
# 4110  Will Never, Ever Purchase an HP Product…<br />...  2015-08-31

# %% [markdown]
# There are cases where a review may receive at least 5 helpful upvotes, but many more downvotes. <br>
# Downvoting was a previously removed feature of Amazon that indicated unhelpful reviews. <br>
# However, we can still account for the presence of downvotes by subtracting the number of upvotes from the total number of votes. <br>  We will use a ratio of upvotes to downvotes to filter out more reviews.

# %%
helpful_df['ratio'] = np.round(helpful_df['helpful_votes']/(helpful_df['total_votes'] - helpful_df['helpful_votes']), 2)

helpful_df = helpful_df[(helpful_df['ratio'] > 1) | (helpful_df['vine'] == 'Y')]

helpful_df.head()
# Out:
#      customer_id product_parent  \
# 561     33788671      942854828
# 622       108604      218670083
# 996     39145251      774078247
# 1454    25575022      516262603
# 4110    52924529      251834115
#
#                                           product_title product_category  \
# 561   ASUS C201 11.6 Inch Chromebook (Rockchip, 4 GB...               PC
# 622   ASUS K501UX 15-inch Gaming Laptop (Intel Core ...               PC
# 996                           Apple MacBook Pro  Laptop               PC
# 1454                                  Lenovo S41 Laptop               PC
# 4110  HP Chromebook 14 Inch Laptop (NVIDIA Tegra K1,...               PC
#
#      star_rating  helpful_votes  total_votes vine verified_purchase  \
# 561            4              5            5    N                 Y
# 622            1              6            6    N                 Y
# 996            1              7            7    N                 Y
# 1454           4              2            4    Y                 N
# 4110           2              6            7    N                 N
#
#                                review_headline  \
# 561                        Awesome Chromebook!
# 622                       Don't buy this junk.
# 996          Bitter experience. Expensive too!
# 1454        Laptop of The Times - No DVD Drive
# 4110  Will Never, Ever Purchase an HP Product…
#
#                                             review_body review_date  ratio
# 561   I was worried that the Rockchip processor woul...  2015-08-31    inf
# 622   Don't buy this laptop, it's good at first but ...  2015-08-31    inf
# 996   I almost forgot about this order, found it acc...  2015-08-31    inf
# 1454  Its a great little laptop. I like the size and...  2015-08-31    1.0
# 4110  Will Never, Ever Purchase an HP Product…<br />...  2015-08-31    6.0

# %% [markdown]
# We will now focus on products with at least 25 reviews that were either mostly helpful or written by those in the Amazon vine program. <br>

# %%
helpful_review_count = helpful_df['product_parent'].value_counts()
select_product_parents = set(helpful_review_count[helpful_review_count >= 25].index.values)

# %%
helpful_df = helpful_df[helpful_df['product_parent'].isin(select_product_parents)]
helpful_df = helpful_df.sort_values('product_title')

# %%
helpful_df
# Out:
#         customer_id product_parent  \
# 304725     28267438      519804412
# 588697     51997017      519804412
# 782848     52717702      519804412
# 407648     50450152      519804412
# 786258     47792218      519804412
# ...             ...            ...
# 6167364    25840050      904063220
# 6155600    48561582      904063220
# 6145948    14700391      904063220
# 6200288    52323503      904063220
# 6209191    13374859      904063220
#
#                                              product_title product_category  \
# 304725                               ASUS Chromebook 11.6"               PC
# 588697                               ASUS Chromebook 11.6"               PC
# 782848                               ASUS Chromebook 11.6"               PC
# 407648                               ASUS Chromebook 11.6"               PC
# 786258                               ASUS Chromebook 11.6"               PC
# ...                                                    ...              ...
# 6167364  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6155600  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6145948  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6200288  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6209191  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
#
#         star_rating  helpful_votes  total_votes vine verified_purchase  \
# 304725            3            495          529    N                 N
# 588697            5              1            2    Y                 N
# 782848            5              3            4    Y                 N
# 407648            5              6            8    N                 Y
# 786258            5              4            5    Y                 N
# ...             ...            ...          ...  ...               ...
# 6167364           1             17           21    N                 N
# 6155600           2             12           13    N                 N
# 6145948           4             37           37    N                 N
# 6200288           1             15           20    N                 N
# 6209191           4             23           23    N                 N
#
#                                            review_headline  \
# 304725   Great Chromebook, but not so great for watchin...
# 588697                                    Great Chromebook
# 782848        ASUS Chromebook C201PA-DS02 11.6-Inch Laptop
# 407648                                      Super pleased!
# 786258   Best Chromebook At The Best Price That I Have ...
# ...                                                    ...
# 6167364             OVERPRICED & TERRIBLE CUSTOMER SERVICE
# 6155600  Amazing Laptop, Finally an Air2 Contender ...B...
# 6145948            Good, BUT Know What You're Getting Into
# 6200288                              Weak Wifi is a killer
# 6209191        Best laptop ever, but I have mixed feelings
#
#                                                review_body review_date  ratio
# 304725   My old Chromebook was the very first HP 11&#34...  2015-07-21  14.56
# 588697   I’ve always been a traditional laptop guy, but...  2015-06-09   1.00
# 782848   I’ve been a long time user of tablets (Kindle ...  2015-05-11   3.00
# 407648   Just to be clear upfront, this is my first Chr...  2015-07-07   3.00
# 786258   This is a simple to set up chromebook that so ...  2015-05-11   4.00
# ...                                                    ...         ...    ...
# 6167364  I bought this laptop for work after considerin...  2011-06-25   4.25
# 6155600  This is a great laptop, and I really wanted it...  2011-07-08  12.00
# 6145948  Fist let me tell you what/where I am coming fr...  2011-07-18    inf
# 6200288  I have owned this for over a month now and I h...  2011-05-19   3.00
# 6209191  [[ASIN:B004NF5RU6 Samsung Series 9 NP900X3A-A0...  2011-05-08    inf
#
# [5249 rows x 13 columns]

# %% [markdown]
# We then further narrow the products to those with negative reviews. <br>
# We define a postive review as a review that issued a product ratings greater than 3. <br>
# We define a negative review as a review that issued a product rating less than or equal to 3. <br>
# Otherwise, we will not be able to produce pros and cons for each product. <br>

# %%
helpful_df = helpful_df.astype({"star_rating":np.int8})

# %%
missing_pos = set() #list of product parents missing positive reviews
missing_neg = set() #list of product parents missing negative reviews

for product_parent in select_product_parents:
    pos_review_mask = helpful_df['star_rating'] > 3
    id_mask = helpful_df['product_parent'] == product_parent

    positive_reviews = helpful_df[pos_review_mask & id_mask]
    negative_reviews = helpful_df[~pos_review_mask & id_mask]

    if len(positive_reviews) == 0:
        print('No positive reviews for product_parent ' + product_parent)
        missing_pos.add(product_parent)

    if len(negative_reviews) == 0:
        print('No negative reviews for product_parent ' + product_parent)
        missing_neg.add(product_parent)

#we only want products with negative reviews
helpful_df = helpful_df[~helpful_df['product_parent'].isin(missing_neg)]
# Out:
# No negative reviews for product_parent 204894625

# %%
helpful_df
# Out:
#         customer_id product_parent  \
# 304725     28267438      519804412
# 588697     51997017      519804412
# 782848     52717702      519804412
# 407648     50450152      519804412
# 786258     47792218      519804412
# ...             ...            ...
# 6167364    25840050      904063220
# 6155600    48561582      904063220
# 6145948    14700391      904063220
# 6200288    52323503      904063220
# 6209191    13374859      904063220
#
#                                              product_title product_category  \
# 304725                               ASUS Chromebook 11.6"               PC
# 588697                               ASUS Chromebook 11.6"               PC
# 782848                               ASUS Chromebook 11.6"               PC
# 407648                               ASUS Chromebook 11.6"               PC
# 786258                               ASUS Chromebook 11.6"               PC
# ...                                                    ...              ...
# 6167364  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6155600  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6145948  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6200288  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6209191  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
#
#          star_rating  helpful_votes  total_votes vine verified_purchase  \
# 304725             3            495          529    N                 N
# 588697             5              1            2    Y                 N
# 782848             5              3            4    Y                 N
# 407648             5              6            8    N                 Y
# 786258             5              4            5    Y                 N
# ...              ...            ...          ...  ...               ...
# 6167364            1             17           21    N                 N
# 6155600            2             12           13    N                 N
# 6145948            4             37           37    N                 N
# 6200288            1             15           20    N                 N
# 6209191            4             23           23    N                 N
#
#                                            review_headline  \
# 304725   Great Chromebook, but not so great for watchin...
# 588697                                    Great Chromebook
# 782848        ASUS Chromebook C201PA-DS02 11.6-Inch Laptop
# 407648                                      Super pleased!
# 786258   Best Chromebook At The Best Price That I Have ...
# ...                                                    ...
# 6167364             OVERPRICED & TERRIBLE CUSTOMER SERVICE
# 6155600  Amazing Laptop, Finally an Air2 Contender ...B...
# 6145948            Good, BUT Know What You're Getting Into
# 6200288                              Weak Wifi is a killer
# 6209191        Best laptop ever, but I have mixed feelings
#
#                                                review_body review_date  ratio
# 304725   My old Chromebook was the very first HP 11&#34...  2015-07-21  14.56
# 588697   I’ve always been a traditional laptop guy, but...  2015-06-09   1.00
# 782848   I’ve been a long time user of tablets (Kindle ...  2015-05-11   3.00
# 407648   Just to be clear upfront, this is my first Chr...  2015-07-07   3.00
# 786258   This is a simple to set up chromebook that so ...  2015-05-11   4.00
# ...                                                    ...         ...    ...
# 6167364  I bought this laptop for work after considerin...  2011-06-25   4.25
# 6155600  This is a great laptop, and I really wanted it...  2011-07-08  12.00
# 6145948  Fist let me tell you what/where I am coming fr...  2011-07-18    inf
# 6200288  I have owned this for over a month now and I h...  2011-05-19   3.00
# 6209191  [[ASIN:B004NF5RU6 Samsung Series 9 NP900X3A-A0...  2011-05-08    inf
#
# [5206 rows x 13 columns]

# %% [markdown]
# Return to [Table of Contents](#table)

# %% [markdown]
# ## 4. Tokenize <a name="token"></a>

# %% [markdown]
# A review can have a lot of mixed sentiment due to discussion of pros and cons. <br>
# Even a 5 star review can have a lot of mixed sentiment, which might affect our modeling. <br>
# To achieve better results, we create sentence tokens from the reviews. <br>
# This allows us to more effectively capture the sentiment behind each product feature in the review.
#
# We will be using `VADER` to help us parse sentiment, specifically the compound score. <br>
# Essentially, the compound score is a measure of whether a sentence is more positive than negative. <br>
#
# According to the documentatation, we can group sentences with:
# - a score higher than 0.05 as positive
# - a score between -0.05 and 0.05 as neutral
# - a score lower than -0.05 as negative
#
# We are specifically interested in sentences with positive and negative sentiment since they are related to pros and cons. <br>
# Sentences with neutral sentiment offer no insight. <br>

# %%
analyzer = SentimentIntensityAnalyzer() #ok for product reviews


def sentence_tokenizer(review):
    """
        Helper function for identifying sentences with 
        positive and negative sentiment in a review via VADER
        
        :params review: a string representation of the review
        
        :returns positive_sentences: a list of strings with positive sentiment
        :returns negative_sentences: a list of strings with negative sentiment
    """
    
    positive_sentences = []
    negative_sentences = []
    
    sentences = set(review.split('.'))
    
    for sentence in sentences:
        if len(sentence) == 0:
            continue
            
        vs = analyzer.polarity_scores(sentence)
        
        #if the sentence has mostly positive sentiment
        if vs['compound'] > 0.05:
            positive_sentences.append(sentence)
        
        #if the sentence has mostly negative sentiment
        elif vs['compound'] < -0.05:
            negative_sentences.append(sentence)
    
    return positive_sentences, negative_sentences

# %%
sentences_list = helpful_df['review_body'].apply(sentence_tokenizer).values

positive_sentences_list = []
negative_sentences_list = []

for sentences in sentences_list:
    positive_sentences_list.append(sentences[0])
    negative_sentences_list.append(sentences[1])
    
helpful_df['positive_sentences'] = positive_sentences_list
helpful_df['negative_sentences'] = negative_sentences_list

# %%
helpful_df.head()
# Out:
#        customer_id product_parent          product_title product_category  \
# 304725    28267438      519804412  ASUS Chromebook 11.6"               PC
# 588697    51997017      519804412  ASUS Chromebook 11.6"               PC
# 782848    52717702      519804412  ASUS Chromebook 11.6"               PC
# 407648    50450152      519804412  ASUS Chromebook 11.6"               PC
# 786258    47792218      519804412  ASUS Chromebook 11.6"               PC
#
#         star_rating  helpful_votes  total_votes vine verified_purchase  \
# 304725            3            495          529    N                 N
# 588697            5              1            2    Y                 N
# 782848            5              3            4    Y                 N
# 407648            5              6            8    N                 Y
# 786258            5              4            5    Y                 N
#
#                                           review_headline  \
# 304725  Great Chromebook, but not so great for watchin...
# 588697                                   Great Chromebook
# 782848       ASUS Chromebook C201PA-DS02 11.6-Inch Laptop
# 407648                                     Super pleased!
# 786258  Best Chromebook At The Best Price That I Have ...
#
#                                               review_body review_date  ratio  \
# 304725  My old Chromebook was the very first HP 11&#34...  2015-07-21  14.56
# 588697  I’ve always been a traditional laptop guy, but...  2015-06-09   1.00
# 782848  I’ve been a long time user of tablets (Kindle ...  2015-05-11   3.00
# 407648  Just to be clear upfront, this is my first Chr...  2015-07-07   3.00
# 786258  This is a simple to set up chromebook that so ...  2015-05-11   4.00
#
#                                        positive_sentences  \
# 304725  [ The HP11 was only able to last all day if I ...
# 588697  [ However, the price is amazing, <br /><br />O...
# 782848  [ I wasn’t sure it would be as fast as my lapt...
# 407648  [ It is uber lightweight and compact, so easy ...
# 786258  [    Movies stream well,    The navy blue cove...
#
#                                        negative_sentences
# 304725  [Well, the quality of the speakers on the C201...
# 588697  [<br /><br />Basically, this is a laptop that ...
# 782848  [I’ve been a long time user of tablets (Kindle...
# 407648                                                 []
# 786258                                                 []

# %% [markdown]
# Return to [Table of Contents](#table)

# %% [markdown]
# ## 5. Text Cleaning <a name="text"></a>

# %%
tag_re = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
backslash_re = re.compile(r'\"') 

#for getting rid of strange characters in text
def remove_strange_chars(text):
    """
        Helper function for removing strange characters present in text
        
        :params text: text string
        
        :returns text: text string after strange characters have been removed
    """
    #remove html tags
    text = tag_re.sub(' ', text) 
    
    #remove backslashes in conjunctions
    text = backslash_re.sub(' ', text)
    
    #remove backslashes around words
    text = text.replace("\\", '')

    return text



lemmatizer = WordNetLemmatizer()

#for processing the text
def text_preprocessing(text):
    
    """
        Helper function for cleaning and lemmatizing the text
        
        :params text: text string
        
        :returns text: text string after cleaning and lemmatization
    """
    
    #match only letters
    text = re.sub('\w*\d\w*', ' ', text) 
    
    #lowercase all text and remove punctuation
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text.lower()) 
    
    #lemmatize text and recombined into one string
    word_list = nltk.word_tokenize(text)
    text = ' '.join([lemmatizer.lemmatize(word) for word in word_list]) 
    
    return text

# %%
helpful_df['positive_sentences'] = helpful_df['positive_sentences'].apply(lambda sentences: 
                                                                [remove_strange_chars(sentence) for sentence in sentences])

helpful_df['negative_sentences'] = helpful_df['negative_sentences'].apply(lambda sentences: 
                                                                [remove_strange_chars(sentence) for sentence in sentences])

# %%
helpful_df['lemmatized_positives'] = helpful_df['positive_sentences'].apply(lambda sentences: 
                                                                [text_preprocessing(sentence) for sentence in sentences])

helpful_df['lemmatized_negatives'] = helpful_df['negative_sentences'].apply(lambda sentences: 
                                                                [text_preprocessing(sentence) for sentence in sentences])

# %%
helpful_df = helpful_df.sort_values('product_title')

helpful_df.head()
# Out:
#         customer_id product_parent  \
# 304725     28267438      519804412
# 72820      21910022      519804412
# 593272     51925793      519804412
# 482481     16913265      519804412
# 429628       478265      519804412
# 725001     49945042      519804412
# 721719     51133542      519804412
# 608572     42951718      519804412
# 620514     33299926      519804412
# 291685     34536212      519804412
# 316832     51311691      519804412
# 350005     50000506      519804412
# 190869       390120      519804412
# 387410     36297644      519804412
# 798806     45094145      519804412
# 304321     44196838      519804412
# 12938       4889696      519804412
# 564265     48973259      519804412
# 813684     52254797      519804412
# 588697     51997017      519804412
# 782848     52717702      519804412
# 407648     50450152      519804412
# 183515     11758430      519804412
# 793125     52990484      519804412
# 794059     31716778      519804412
# 786258     47792218      519804412
# 782754     29660394      519804412
# 797842     15736185      519804412
# 567159     44802369      519804412
# 809434     27394191      519804412
# ...             ...            ...
# 6241729    13351440      904063220
# 6129114    52673283      904063220
# 6201517    46471612      904063220
# 6190982    53061566      904063220
# 6190213    48499269      904063220
# 6169210    13378518      904063220
# 6178521    21495000      904063220
# 6177721    52916255      904063220
# 6167364    25840050      904063220
# 6155600    48561582      904063220
# 6145948    14700391      904063220
# 6228969    46815836      904063220
# 6180444    25756071      904063220
# 6223451    48115838      904063220
# 6144874    50626670      904063220
# 6221349    12684170      904063220
# 6221001    44244330      904063220
# 6217064    12418876      904063220
# 6213417    37305208      904063220
# 6208905    12183445      904063220
# 6142775    51000199      904063220
# 6206645    41519000      904063220
# 6127549    14682517      904063220
# 6055411    47970359      904063220
# 6040874    50771785      904063220
# 6113607    45633039      904063220
# 6084906    14296305      904063220
# 6200288    52323503      904063220
# 6222035    25924476      904063220
# 6209191    13374859      904063220
#
#                                              product_title product_category  \
# 304725                               ASUS Chromebook 11.6"               PC
# 72820                                ASUS Chromebook 11.6"               PC
# 593272                               ASUS Chromebook 11.6"               PC
# 482481                               ASUS Chromebook 11.6"               PC
# 429628                               ASUS Chromebook 11.6"               PC
# 725001                               ASUS Chromebook 11.6"               PC
# 721719                               ASUS Chromebook 11.6"               PC
# 608572                               ASUS Chromebook 11.6"               PC
# 620514                               ASUS Chromebook 11.6"               PC
# 291685                               ASUS Chromebook 11.6"               PC
# 316832                               ASUS Chromebook 11.6"               PC
# 350005                               ASUS Chromebook 11.6"               PC
# 190869                               ASUS Chromebook 11.6"               PC
# 387410                               ASUS Chromebook 11.6"               PC
# 798806                               ASUS Chromebook 11.6"               PC
# 304321                               ASUS Chromebook 11.6"               PC
# 12938                                ASUS Chromebook 11.6"               PC
# 564265                               ASUS Chromebook 11.6"               PC
# 813684                               ASUS Chromebook 11.6"               PC
# 588697                               ASUS Chromebook 11.6"               PC
# 782848                               ASUS Chromebook 11.6"               PC
# 407648                               ASUS Chromebook 11.6"               PC
# 183515                               ASUS Chromebook 11.6"               PC
# 793125                               ASUS Chromebook 11.6"               PC
# 794059                               ASUS Chromebook 11.6"               PC
# 786258                               ASUS Chromebook 11.6"               PC
# 782754                               ASUS Chromebook 11.6"               PC
# 797842                               ASUS Chromebook 11.6"               PC
# 567159                               ASUS Chromebook 11.6"               PC
# 809434                               ASUS Chromebook 11.6"               PC
# ...                                                    ...              ...
# 6241729  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6129114  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6201517  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6190982  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6190213  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6169210  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6178521  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6177721  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6167364  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6155600  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6145948  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6228969  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6180444  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6223451  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6144874  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6221349  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6221001  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6217064  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6213417  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6208905  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6142775  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6206645  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6127549  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6055411  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6040874  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6113607  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6084906  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6200288  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6222035  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
# 6209191  Samsung Series 9 NP900X3A-A03US 13.3-Inch Lapt...               PC
#
#          star_rating  helpful_votes  total_votes vine verified_purchase  \
# 304725             3            495          529    N                 N
# 72820              1              6            9    N                 Y
# 593272             5              0            0    Y                 N
# 482481             5              9           10    N                 Y
# 429628             5             12           15    N                 Y
# 725001             4             17           22    Y                 N
# 721719             5              5            6    N                 Y
# 608572             5              4            5    Y                 N
# 620514             5              6            7    N                 Y
# 291685             5             10           10    N                 Y
# 316832             5             17           20    N                 Y
# 350005             3              5            9    N                 Y
# 190869             1              7            9    N                 Y
# 387410             5              7            8    N                 Y
# 798806             5              8           11    Y                 N
# 304321             3             15           17    N                 Y
# 12938              5             31           35    N                 Y
# 564265             5             27           30    N                 Y
# 813684             5              4            7    Y                 N
# 588697             5              1            2    Y                 N
# 782848             5              3            4    Y                 N
# 407648             5              6            8    N                 Y
# 183515             1             20           22    N                 Y
# 793125             5             55           63    N                 N
# 794059             5            643          675    N                 Y
# 786258             5              4            5    Y                 N
# 782754             5            344          380    Y                 N
# 797842             5              2            5    Y                 N
# 567159             5              5            5    N                 Y
# 809434             4            184          206    N                 Y
# ...              ...            ...          ...  ...               ...
# 6241729            5             98          104    N                 N
# 6129114            1              6           10    N                 N
# 6201517            1             24           30    N                 N
# 6190982            4             19           21    N                 N
# 6190213            5              6            6    N                 Y
# 6169210            1             11           16    N                 N
# 6178521            1             14           16    N                 N
# 6177721            2              8           10    N                 N
# 6167364            1             17           21    N                 N
# 6155600            2             12           13    N                 N
# 6145948            4             37           37    N                 N
# 6228969            5             52           52    N                 Y
# 6180444            1             15           21    N                 Y
# 6223451            2             16           22    N                 Y
# 6144874            5              6            6    N                 N
# 6221349            5              7            7    N                 Y
# 6221001            4             75           78    N                 N
# 6217064            3             35           44    N                 Y
# 6213417            5              7            7    N                 N
# 6208905            4              5            6    N                 Y
# 6142775            3              6            7    N                 N
# 6206645            1             82           91    N                 N
# 6127549            1             20           27    N                 N
# 6055411            1              7           10    N                 N
# 6040874            1              5            9    N                 N
# 6113607            5             20           22    N                 N
# 6084906            2              5            6    N                 N
# 6200288            1             15           20    N                 N
# 6222035            5             14           15    N                 N
# 6209191            4             23           23    N                 N
#
#                                            review_headline  \
# 304725   Great Chromebook, but not so great for watchin...
# 72820    The second one I bought is excellent! / Beware...
# 593272                  I LOVE This Little ASUS Chromebook
# 482481   The ASUS C201PA: Affordable, Stylish, Fast, Ri...
# 429628                            A capable little machine
# 725001                            Excellent Device Overall
# 721719   A snappy little Chromebook, feel free to say g...
# 608572   Price, speed, battery life and portability...y...
# 620514                                  One word - AMAZING
# 291685                               Chromebook + Rockchip
# 316832                                    It's Great......
# 350005   Stay away from refurbished or warehouse specim...
# 190869   Buy an extra charger with it, or a fire exting...
# 387410         Another great Chromebook offering from Asus
# 798806             Sure meets my needs - I love this thing
# 304321     Overall good, with one design drawback (for me)
# 12938                    Look no further. This is the one.
# 564265   One of the best electronics purchase I have ev...
# 813684              We have met the friendly and it's ASUS
# 588697                                    Great Chromebook
# 782848        ASUS Chromebook C201PA-DS02 11.6-Inch Laptop
# 407648                                      Super pleased!
# 183515   Other than that it was going great. Still wait...
# 793125   Thrilled! Everything is great but the screen, ...
# 794059            Couldn't be happier with this Chromebook
# 786258   Best Chromebook At The Best Price That I Have ...
# 782754                                Excellent Chromebook
# 797842   Small, light, fast, solid, and great battery l...
# 567159             A Review for First-Time Chrome OS Users
# 809434                      Best Chromebook Experience Yet
# ...                                                    ...
# 6241729                                                Wow
# 6129114                                 Unusably slow WiFi
# 6201517  Samsung NP900X3A - Do not buy - Touchpad deter...
# 6190982                        samsung almost got it right
# 6190213                                     Almost Perfect
# 6169210                       Stay Away from this Computer
# 6178521                 Horrible WI-FI Issues ** AVOID ***
# 6177721                                      I returned it
# 6167364             OVERPRICED & TERRIBLE CUSTOMER SERVICE
# 6155600  Amazing Laptop, Finally an Air2 Contender ...B...
# 6145948            Good, BUT Know What You're Getting Into
# 6228969                                       Great Laptop
# 6180444                                  Major WIFI issues
# 6223451                                    Multiple issues
# 6144874                      Replaced $4,500 desk monster!
# 6221349  Amazing Design, Great Performance and Surprisi...
# 6221001  Excellent piece of hardware, but not a desktop...
# 6217064                                      Disappointing
# 6213417         GREAT laptop after you learn how to use it
# 6208905                        Best laptop,less WIFI issue
# 6142775                          Bad wifi hampers mobility
# 6206645     Extremely Elegant Laptop but with a major flaw
# 6127549          DO NOT PURCHASE THIS LAPTOP FROM SAMSUNG!
# 6055411                                   Rushed to market
# 6040874      Looks great, is very light, but it is useless
# 6113607                               The truth about wifi
# 6084906                           Completely Dissappointed
# 6200288                              Weak Wifi is a killer
# 6222035                           Gorgeous power on the go
# 6209191        Best laptop ever, but I have mixed feelings
#
#                                                review_body review_date  ratio  \
# 304725   My old Chromebook was the very first HP 11&#34...  2015-07-21  14.56
# 72820    Previous post: Actually, it had been my favori...  2015-08-21   2.00
# 593272   This ASUS Chromebook C201PA-DS02 is super fast...  2015-06-09    NaN
# 482481   Just buy it. It's light. The battery lasts a l...  2015-06-25   9.00
# 429628   I've never used a Chrome OS device before. Wit...  2015-07-04   4.00
# 725001   If you've not seen a Chromebook before THIS IS...  2015-05-20   3.40
# 721719   A recent convert from Windows 8.1, I was fed u...  2015-05-21   5.00
# 608572   I have had the pleasure of using this ASUS Chr...  2015-06-06   4.00
# 620514   This product has exceeded my expectations, it ...  2015-06-05   6.00
# 291685   Chromebooks are awesome. If you are into brows...  2015-07-23    inf
# 316832   just make sure you know what it can and cannot...  2015-07-20   5.67
# 350005   Bought a refurbished version-thought I was sav...  2015-07-15   1.25
# 190869   I have had this laptop for 3 months and the ch...  2015-08-06   3.50
# 387410   I purchased this as a replacement for my Asus ...  2015-07-10   7.00
# 798806   Being a non tech sort of person I am unable to...  2015-05-09   2.67
# 304321   Love the Chrome OS.  This processor is a littl...  2015-07-21   7.50
# 12938    This Asus machine is the best Chromebook for t...  2015-08-30   7.75
# 564265   Boots in seconds<br />My battery is averaging ...  2015-06-13   9.00
# 813684   Let's talk about ASUS.<br /><br />It's not as ...  2015-05-07   1.33
# 588697   I’ve always been a traditional laptop guy, but...  2015-06-09   1.00
# 782848   I’ve been a long time user of tablets (Kindle ...  2015-05-11   3.00
# 407648   Just to be clear upfront, this is my first Chr...  2015-07-07   3.00
# 183515   Less than a month of normal use and my laptop ...  2015-08-07  10.00
# 793125   Updated!<br />First impressions: Absolutely wo...  2015-05-10   6.88
# 794059   Couldn't be happier with this Chromebook.  I a...  2015-05-10  20.09
# 786258   This is a simple to set up chromebook that so ...  2015-05-11   4.00
# 782754   This is my first time using a Chromebook and I...  2015-05-11   9.56
# 797842   I didn't quite know what to expect from this l...  2015-05-09   0.67
# 567159   If you are considering purchasing a Chromebook...  2015-06-12    inf
# 809434   I was in the market for a 11.6&#34; Chromebook...  2015-05-07   8.36
# ...                                                    ...         ...    ...
# 6241729  I bought this laptop on the 30th not from Beac...  2011-04-01  16.33
# 6129114  The wifi on the Samsung Series 9 is incredibly...  2011-08-04   1.50
# 6201517  Touchpad by Synaptics is seriously defective. ...  2011-05-17   4.00
# 6190982  I really wanted this thing, right from the fir...  2011-05-30   9.50
# 6190213  I can find very little wrong with this ultra-p...  2011-05-31    inf
# 6169210  Okay -- it is a great computer except for one ...  2011-06-23   2.20
# 6178521  I have a 6 year old dell laptop with a wireles...  2011-06-13   7.00
# 6177721  I really wanted to like and keep this laptop. ...  2011-06-14   4.00
# 6167364  I bought this laptop for work after considerin...  2011-06-25   4.25
# 6155600  This is a great laptop, and I really wanted it...  2011-07-08  12.00
# 6145948  Fist let me tell you what/where I am coming fr...  2011-07-18    inf
# 6228969  I was on the market for a very light, thin lap...  2011-04-15    inf
# 6180444  Love the laptop but what the heck?! I didn't p...  2011-06-10   2.50
# 6223451  I was excited to get this laptop to replace my...  2011-04-22   2.67
# 6144874  ok, so it isn't the Lenovo W701ds that I repla...  2011-07-19    inf
# 6221349  I have owned this laptop for a little under a ...  2011-04-24    inf
# 6221001  Got mine from the Microsoft Store, where they ...  2011-04-25  25.00
# 6217064  I really wanted to like this laptop-- and was ...  2011-04-29   3.89
# 6213417  Just a countervailing opinion to some of the r...  2011-05-03    inf
# 6208905  This is my first review for any product on the...  2011-05-09   5.00
# 6142775  I loved this computer except for the weak wifi...  2011-07-21   6.00
# 6206645  This is a beautiful and extremely well designe...  2011-05-11   9.11
# 6127549  I purchased the Samsung Series 9 Laptop comput...  2011-08-05   2.86
# 6055411  The touchpad is too touchy; get ready for an e...  2011-10-09   2.33
# 6040874  I recently got this laptop as a reward at work...  2011-10-22   1.25
# 6113607  Great machine, but it took my IT department a ...  2011-08-19  10.00
# 6084906  I tend to purchase higher end computers. For e...  2011-09-13   5.00
# 6200288  I have owned this for over a month now and I h...  2011-05-19   3.00
# 6222035  Main Usage:<br />Compuer Programming (Visual S...  2011-04-23  14.00
# 6209191  [[ASIN:B004NF5RU6 Samsung Series 9 NP900X3A-A0...  2011-05-08    inf
#
#                                         positive_sentences  \
# 304725   [  PORTABILITY(5/5): The C201 is slightly ligh...
# 72820    [  3) Additional storage    It comes with a mi...
# 593272   [ I like that a LOT,   It's lightweight and ex...
# 482481   [ It gets you where you want to go,  It picks ...
# 429628   [ For the touchpad, well, I've used an old Del...
# 725001   [5 GB free after space taken by the OS,   Shor...
# 721719   [ When you create documents you have the optio...
# 608572   [ Yep, 10 seconds! Another 10 seconds to boot ...
# 620514   [ Sound quality is decently good - Speakers at...
# 291685   [ Their  C  series laptops are tops for design...
# 316832   [  IT is worth the money, just make sure you k...
# 350005                                                  []
# 190869                                                  []
# 387410   [ All in all, I like this better than what I h...
# 798806   [  Being a non tech person, it took me 15 minu...
# 304321   [Love the Chrome OS,   Build quality, screen, ...
# 12938    [This Asus machine is the best Chromebook for ...
# 564265   [ I really works awesome! I recommend this 100...
# 813684   [  One thing: On the Amazon Products page it l...
# 588697   [  The battery claims to last 13 hours and, wh...
# 782848   [ It’s a good size, a true laptop fit, Big eno...
# 407648   [ My needs, and the reason I purchased this de...
# 183515   [ Less than a year later the touch pad is no l...
# 793125   [ This thing feels tiny, snappy in most tasks,...
# 794059   [  The build quality is also really solid for ...
# 786258   [   The navy blue cover is very attractive and...
# 782754   [ Very cool,  With everything online, like Net...
# 797842   [ No bending, no over-opening, and a great, re...
# 567159   [  =============================== *Bottom Lin...
# 809434   [ - Quality, feels nice and light and does not...
# ...                                                    ...
# 6241729  [  The duraluminum body is magnificent - it is...
# 6129114  [ I have a strong signal, and all other WiFi l...
# 6201517  [ They promise a call back from Level 2 within...
# 6190982  [  It makes me more than a little frustrated t...
# 6190213  [  - Best keyboard and touchpad combo on a lap...
# 6169210  [Okay -- it is a great computer except for one...
# 6178521  [0 of this and fix this huge issue,  There is ...
# 6177721  [  I agree with another reviewer in that it wo...
# 6167364  [ Contrast this to my excellent experiences wi...
# 6155600  [ You have to be almost ontop of a Hotspot in ...
# 6145948  [0 port - at least on one side    All and all ...
# 6228969  [  I still haven't experienced any WiFi issues...
# 6180444  [Love the laptop but what the heck?! I didn't ...
# 6223451  [ is great, BUT I have multiple issues after t...
# 6144874  [  I always run full brightness on the monitor...
# 6221349  [    Overall, I think this is a delicious pack...
# 6221001  [ So this unit comes clean (they remove the bl...
# 6217064  [ I could buy a dongle, sure, as some people h...
# 6213417  [ Trust me, I have gone out of my way to find ...
# 6208905  [ The Track pad is great if you know how to pl...
# 6142775  [  I bought it for its beauty but needed it fo...
# 6206645  [  Maybe it takes a certain percentage of lapt...
# 6127549  [ After 45 minutes of waiting and negotiating,...
# 6055411  [The touchpad is too touchy; get ready for an ...
# 6040874  [I recently got this laptop as a reward at wor...
# 6113607  [      SAMSUNG ARE YOU LISTENING?  YOU NEED TO...
# 6084906  [  I'll definitely avoid purchasing Samsung pr...
# 6200288                                                 []
# 6222035  [  - Not likely to use Good screen / Keyboard ...
# 6209191  [ We changed to an advanced router and it solv...
#
#                                         negative_sentences  \
# 304725   [ My C201 has been dropped several times and s...
# 72820    [ I virtually have an extremely inexpensive an...
# 593272   [  There is only one thing that I don't like a...
# 482481   [ I have no intention of installing Linux on t...
# 429628   [ This is disappointing,  But amazingly I have...
# 725001   [pdf (read-only)  --Update--  One last thing, ...
# 721719   [ Another thing you'll notice with a Chromeboo...
# 608572   [ I was wrong,  It seems odd not to have a 3, ...
# 620514   [ The 13 hours included about 7-8 hours of non...
# 291685                                                  []
# 316832                                                  []
# 350005   [ Ended up paying more overall than if I had j...
# 190869   [ It works just fine with everything in the la...
# 387410   [ This edge is flatter now which means the spe...
# 798806   [  I am terrible when it comes to the use of a...
# 304321   [  I would buy again but that rocking when i p...
# 12938    [ If you have a limited budget and want a qual...
# 564265   [ It  seems  weak and delicate,  Even though I...
# 813684   [ If I need to tell you this is a case of a mi...
# 588697   [ The only downside is that is seems a little ...
# 782848   [ The sound, while not the best, is still very...
# 407648                                                  []
# 183515                                                  []
# 793125   [  Since the specs available for this model se...
# 794059   [Couldn't be happier with this Chromebook,   A...
# 786258                                                  []
# 782754   [  Because of my big fingers I'm not a fan of ...
# 797842                                                  []
# 567159   [ However, if you 1) lack a high-speed interne...
# 809434   [ No SD card slot,  I recently sold my HP Chro...
# ...                                                    ...
# 6241729  [  After the first few uses, I started running...
# 6129114  [The wifi on the Samsung Series 9 is incredibl...
# 6201517  [    Keyboard - unless you bang on the keyboar...
# 6190982  [ Its a physical limitation of the radio on th...
# 6190213  [0!    CONS  - Relatively small hard drive,   ...
# 6169210  [  This is a Samsung design issue and they ref...
# 6178521        [ Avoid until they come out with version 2]
# 6177721  [  They both had great signal but the Samsung ...
# 6167364  [ While the Series 9 is an attractive looking ...
# 6155600  [  > Macbook Air2 - Full bars and ~35Mbps down...
# 6145948  [  Now, before you go off half cocked and orde...
# 6228969  [  The laptop is VERY light, you can pick it u...
# 6180444                                                 []
# 6223451  [ The battery life is weak, I get about 3,  Wo...
# 6144874                                                 []
# 6221349  [ Its footprint is easily one of the lowest if...
# 6221001  [  Unfortunately, I couldn't see an easy way t...
# 6217064  [ The wifi issues that many people have mentio...
# 6213417  [ My only concern is that the black color coul...
# 6208905  [ I have 500$ hp pavilion laptop that have ful...
# 6142775  [  Also sometimes, the signal was too weak for...
# 6206645  [  The broadcom card included with this laptop...
# 6127549  [ By then I had determined from a CompUSA live...
# 6055411  [  Avoid this computer at any cost -- and espe...
# 6040874                                                 []
# 6113607  [Great machine, but it took my IT department a...
# 6084906  [  Now I regret making my hasty decision and w...
# 6200288  [I have owned this for over a month now and I ...
# 6222035  [ (I mean really Thin, bare SSD drive should b...
# 6209191  [ The wifi didn't work well,  Signal seems wea...
#
#                                       lemmatized_positives  \
# 304725   [portability the is slightly lighter and ha a ...
# 72820    [additional storage it come with a micro sd sl...
# 593272   [i like that a lot, it s lightweight and extre...
# 482481   [it get you where you want to go, it pick up a...
# 429628   [for the touchpad well i ve used an old dell a...
# 725001   [gb free after space taken by the o, short ver...
# 721719   [when you create document you have the option ...
# 608572   [yep second another second to boot up chrome a...
# 620514   [sound quality is decently good speaker at the...
# 291685   [their c series laptop are top for design batt...
# 316832   [it is worth the money, just make sure you kno...
# 350005                                                  []
# 190869                                                  []
# 387410   [all in all i like this better than what i had...
# 798806   [being a non tech person it took me minute whi...
# 304321   [love the chrome o, build quality screen keybo...
# 12938    [this asus machine is the best chromebook for ...
# 564265   [i really work awesome i recommend this, this ...
# 813684   [one thing on the amazon product page it list ...
# 588697   [the battery claim to last hour and while it ’...
# 782848   [it ’ s a good size a true laptop fit big enou...
# 407648   [my need and the reason i purchased this devic...
# 183515   [le than a year later the touch pad is no long...
# 793125   [this thing feel tiny snappy in most task ha a...
# 794059   [the build quality is also really solid for a ...
# 786258   [the navy blue cover is very attractive and so...
# 782754   [very cool, with everything online like netfli...
# 797842   [no bending no over opening and a great respon...
# 567159   [bottom line if you are looking for a bare bon...
# 809434   [quality feel nice and light and doe not flex,...
# ...                                                    ...
# 6241729  [the duraluminum body is magnificent it is stu...
# 6129114  [i have a strong signal and all other wifi lap...
# 6201517  [they promise a call back from level within ho...
# 6190982  [it make me more than a little frustrated that...
# 6190213  [best keyboard and touchpad combo on a laptop ...
# 6169210  [okay it is a great computer except for one se...
# 6178521  [of this and fix this huge issue, there is a s...
# 6177721  [i agree with another reviewer in that it work...
# 6167364  [contrast this to my excellent experience with...
# 6155600  [you have to be almost ontop of a hotspot in o...
# 6145948  [port at least on one side all and all i m hap...
# 6228969  [i still haven t experienced any wifi issue li...
# 6180444  [love the laptop but what the heck i didn t pa...
# 6223451  [is great but i have multiple issue after the ...
# 6144874  [i always run full brightness on the monitor, ...
# 6221349  [overall i think this is a delicious package, ...
# 6221001  [so this unit come clean they remove the bloat...
# 6217064  [i could buy a dongle sure a some people have ...
# 6213417  [trust me i have gone out of my way to find fa...
# 6208905  [the track pad is great if you know how to pla...
# 6142775  [i bought it for it beauty but needed it for t...
# 6206645  [maybe it take a certain percentage of laptop ...
# 6127549  [after minute of waiting and negotiating the b...
# 6055411  [the touchpad is too touchy get ready for an e...
# 6040874  [i recently got this laptop a a reward at work...
# 6113607  [samsung are you listening you need to help pe...
# 6084906  [i ll definitely avoid purchasing samsung prod...
# 6200288                                                 []
# 6222035  [not likely to use good screen keyboard lighti...
# 6209191  [we changed to an advanced router and it solve...
#
#                                       lemmatized_negatives
# 304725   [my ha been dropped several time and still ha ...
# 72820    [i virtually have an extremely inexpensive and...
# 593272   [there is only one thing that i don t like abo...
# 482481   [i have no intention of installing linux on th...
# 429628   [this is disappointing, but amazingly i have n...
# 725001   [pdf read only update one last thing if your a...
# 721719   [another thing you ll notice with a chromebook...
# 608572   [i wa wrong, it seems odd not to have a, thin ...
# 620514   [the hour included about hour of non stop yout...
# 291685                                                  []
# 316832                                                  []
# 350005   [ended up paying more overall than if i had ju...
# 190869   [it work just fine with everything in the lapt...
# 387410   [this edge is flatter now which mean the speak...
# 798806   [i am terrible when it come to the use of a to...
# 304321   [i would buy again but that rocking when i put...
# 12938    [if you have a limited budget and want a quali...
# 564265   [it seems weak and delicate, even though i hav...
# 813684   [if i need to tell you this is a case of a mis...
# 588697   [the only downside is that is seems a little s...
# 782848   [the sound while not the best is still very go...
# 407648                                                  []
# 183515                                                  []
# 793125   [since the spec available for this model seem ...
# 794059   [couldn t be happier with this chromebook, aft...
# 786258                                                  []
# 782754   [because of my big finger i m not a fan of the...
# 797842                                                  []
# 567159   [however if you lack a high speed internet con...
# 809434   [no sd card slot, i recently sold my hp chrome...
# ...                                                    ...
# 6241729  [after the first few us i started running into...
# 6129114  [the wifi on the samsung series is incredibly ...
# 6201517  [keyboard unless you bang on the keyboard you ...
# 6190982  [it a physical limitation of the radio on this...
# 6190213  [con relatively small hard drive, limited acce...
# 6169210  [this is a samsung design issue and they refus...
# 6178521           [avoid until they come out with version]
# 6177721  [they both had great signal but the samsung on...
# 6167364  [while the series is an attractive looking lap...
# 6155600  [macbook full bar and download dell full bar a...
# 6145948  [now before you go off half cocked and order i...
# 6228969  [the laptop is very light you can pick it up w...
# 6180444                                                 []
# 6223451  [the battery life is weak i get about, worse i...
# 6144874                                                 []
# 6221349  [it footprint is easily one of the lowest if n...
# 6221001  [unfortunately i couldn t see an easy way to r...
# 6217064  [the wifi issue that many people have mentione...
# 6213417  [my only concern is that the black color could...
# 6208905  [i have hp pavilion laptop that have full bar ...
# 6142775  [also sometimes the signal wa too weak for it ...
# 6206645  [the broadcom card included with this laptop i...
# 6127549  [by then i had determined from a compusa live ...
# 6055411  [avoid this computer at any cost and especiall...
# 6040874                                                 []
# 6113607  [great machine but it took my it department a ...
# 6084906  [now i regret making my hasty decision and wis...
# 6200288  [i have owned this for over a month now and i ...
# 6222035  [i mean really thin bare ssd drive should be t...
# 6209191  [the wifi didn t work well, signal seems weak ...
#
# [5206 rows x 17 columns]

# %% [markdown]
# We save the data at this stage since it can take quite a few minutes to reach this checkpoint.

# %%
if 'helpful_df.pkl.gz' not in os.listdir('data'):
    helpful_df.to_pickle('./data/helpful_df.pkl.gz', compression = 'gzip')

else:
    helpful_df = pd.read_pickle('./data/helpful_df.pkl.gz', compression = 'gzip')

# %% [markdown]
# Return to [Table of Contents](#table)

# %% [markdown]
# ## 6. Modeling <a name="model"></a>

# %% [markdown]
# We use the bidirectional feature importance of logistic regression to identify pros and cons from the n-grams produced from the sentence tokens of reviews. <br>
# We then use word2vec to map these specific pros and cons n-grams to more general product features i.e. aspects.

# %%
def find_bad_phrases(vocab_dict):
    """
        Helper function to identify n-grams 
        to ignore because they are unhelpful
        
        :params vocab_dict: dictionary of indices and words from the vectorizer
                            with indices as the keys and words as the values
                            
        :returns bad_keys: a set of n-gram strings to ignore
    """
    
    bad_keys = []

    for key, value in vocab_dict.items():
        doc = nlp(value)
        pos_list = [] #parts of speech list

        tokens = value.split(' ')
        
        #ignore tokens that contain duplicate words
        if len(tokens) != len(set(tokens)):
            bad_keys.append(key)
            continue
        
        for token in doc:
            pos_list.append(token.pos_)
            
            #ignore tokens with text lengths that 
            #are less than 3 characters long,
            if len(token.text) < 3:
                bad_keys.append(key)
                continue
        
        #ignore ngrams with the label 'X'
        #this means that they cannot be assigned a part of speech tag
        if 'X' in pos_list:
            bad_keys.append(key)
            continue
        
        
        #ignore certain parts-of-speech combinations of words
        bad_pos_combos = [['NOUN', 'ADV'], ['ADV', 'ADP'], ['ADV', 'NOUN'], ['VERB', 'ADJ'], 
                          ['NOUN', 'VERB'], ['NUM', 'NOUN'], ['VERB', 'VERB'], ['ADV', 'ADJ'], 
                          ['PROPN', 'NOUN'], ['ADV', 'ADV'], ['ADV', 'VERB'], ['ADP', 'ADV'], 
                          ['ADP', 'ADJ'], ['NUM', 'ADJ'], ['VERB', 'ADV'], ['ADP', 'VERB'], 
                          ['ADJ', 'ADJ'], ['ADV', 'NUM'], ['VERB', 'NUM'], ['ADJ', 'VERB'], 
                          ['DET', 'NOUN'], ['NOUN', 'NUM'], ['ADJ', 'ADV'], ['ADV', 'VERB'], 
                          ['ADV', 'ADV'], ['NOUN', 'ADJ'], ['VERB', 'NOUN', 'VERB'], 
                          ['VERB', 'VERB', 'NOUN'], ['PRON', 'VERB'], ['ADP', 'NOUN']]

            
        if pos_list in bad_pos_combos:
            bad_keys.append(key)
            continue
        
        
        #ignore ngrams that are not related to the aspect words
        aspects = ['battery', 'ports', 'price', 'hard drive', 'processor speed', 'screen', 
           'ergonomic', 'fan cooling', 'sound', 'build quality', 'ram']
        
        #some values need to be hard coded in since word2vec
        #does not recognize ssd or solid state as well
        if 'solid' in tokens:
            if 'state' in tokens:
                continue

        if 'ssd' in tokens:
            continue
                
        
        #check to see if the word is related to any aspects
        #we consider a word to be related if it has a 
        #cosine similarity score of at least 0.4
        aspect_cnt = 0
        
        for aspect in aspects:
            try:
                similarity_score = model.n_similarity(aspect.split(' '), tokens) 
                if similarity_score >= 0.4:
                    aspect_cnt += 1
            except:
                continue
            
        #if the ngram is unrelated to any aspects, ignore it
        if aspect_cnt == 0:
            bad_keys.append(key)
                    

    return set(bad_keys)

# %%
def modeling(X, y, cv):
    """
        Function that uses bidirectional feature importance of logistic
        regression to separate out pros and cons
        
        :params X: frequency count of words used in review sentences as a matrix
        :params y: labels of whether the sentence is positive or not
        :params cv: vectorizer that was used to produce X
        
        :returns pros_list: a list of n-gram strings that could 
                            indicate positive product features
        :returns cons_list: a list of n-gram strings that could 
                            indicate negative product features
    """
    
    #use the best logistic regression model to fit on the 
    #matrix representation of the review sentences
    
    hyper_param_grid = {'C': [0.001, 0.01, 0.1, 1, 
                              10, 100, 1000, 10000]}
    

    lr = GridSearchCV(LogisticRegression(solver='saga', max_iter = 10000), 
                      hyper_param_grid, cv = 3, n_jobs=-1)

    lr.fit(X, y)


    # we use the beta coefficient values from logistic regression
    # to identify the ngrams associated with positive and negative snetiment

    model_coefs = lr.best_estimator_.coef_[0,:]
    
    #we sort the ngrams based on their beta coefficient value
    #which could be negative to postive,
    #indicating negative or positive sentiment respectively
    model_keys = np.argsort(model_coefs)

    
    #use vectorizer to generate a dictionary that maps indices to words
    #in other words, the key is the index and the value is the word
    vocab_dict = {v: k for k, v in cv.vocabulary_.items()}
    
    #find bad ngrams to ignore because they are unhelpful
    bad_keys = find_bad_phrases(vocab_dict)
    
    
    #find where the positive beta coefficients began
    #in order to separate negative sentiment ngrams from positive ones
    split_idx = 0

    for idx, key in enumerate(model_keys):
        if model_coefs[key] > 0:
            split_idx = idx
            break
    
    #split ngrams into positive and negative groups
    #sorted by their respective beta coefficient value
    neg_idx_list = model_keys[:split_idx]
    pos_idx_list = model_keys[split_idx:][::-1]
    
    
    #generate a filtered list of ngrams with positive sentiment
    #this is what we will consider as the pros
    #we will include ngrams if they are not in the list of bad ngrams to ignore
    pros_list = [(vocab_dict[pos_idx], model_coefs[pos_idx]) 
                 for pos_idx in pos_idx_list if pos_idx not in bad_keys]
    
    
    #generate a filtered list of ngrams with negative sentiment
    #this is what we will consider as the cons
    #we will include ngrams if they are not in the list of bad ngrams to ignore
    cons_list = [(vocab_dict[neg_idx], model_coefs[neg_idx])
                for neg_idx in neg_idx_list if neg_idx not in bad_keys]

    
    return pros_list, cons_list

# %%
def pros_and_cons(df, product_parent, stopwords):
    """
        Function for generating specific pros and cons for each product parent
        
        :params df: dataframe containing 
        :params product_parent: product parent ID string
        :params stopwords: a set of stopwords to modify and use
        
        :returns modeling: output from modeling function, 
                           which is a list of pros and a list of cons
    """
    
    
    product_parent_mask = df['product_parent'] == product_parent
    
    #add words in the title to the stopwords
    #make sure to process the title the same way the sentences were done
    title = df.loc[product_parent_mask, 'product_title'].values[0]
    title = remove_strange_chars(title)
    title = text_preprocessing(title)
    title_words = [word for word in title.split(' ')]
    
    
    title_words = set(title_words)

    stopwords = orig_stopwords.union(title_words)
    
    stopwords = [remove_strange_chars(stopword) for stopword in stopwords]
    stopwords = [text_preprocessing(stopword) for stopword in stopwords]
    
    
    #get positive and negative sentences
    lemmatized_positive_list = df.loc[product_parent_mask, 'lemmatized_positives'].values
    lemmatized_negative_list = df.loc[product_parent_mask, 'lemmatized_negatives'].values
    
    positive_sentences = []
    
    for lemmatized_positive in lemmatized_positive_list:
        if len(lemmatized_positive) == 0:
            continue
        positive_sentences.extend(lemmatized_positive)
    
    negative_sentences = []
    
    for lemmatized_negative in lemmatized_negative_list:
        if len(lemmatized_negative) == 0:
            continue
        negative_sentences.extend(lemmatized_negative)
    
    #concatenate postive and negative sentences together
    all_sentences = []
    all_sentences.extend(positive_sentences)
    all_sentences.extend(negative_sentences)
    

    #create labels based on order sentences were added, 
    #1 being positive, 0 being negative
    y = [1]*len(positive_sentences) + [0]*len(negative_sentences)
    
    
    #create features from words
    cv = CountVectorizer(ngram_range=(2,3), stop_words=stopwords, min_df = 2).fit(all_sentences)
    X = cv.transform(all_sentences)
    
    return modeling(X, y, cv)

# %%
def aspect_generator(aspects, ngram_list):
    
    """
        Function for mapping n-grams to aspects
        
        
        :params aspects: list of aspects as strings
        :params ngram_list: list of n-grams to match aspects to
        
        :returns aspect_dict: dictionary of n-grams and aspects with 
                              n-grams as keys, and the aspects they match to
                              as values, possibly more than one aspect
    """

    
    aspect_dict = defaultdict(list)
    
    ngram_list = [ngram[0] for ngram in ngram_list]
    
    for aspect in aspects:
        for ngram in ngram_list:
            try:
                similarity_score = model.n_similarity(aspect.split(' '), ngram.split(' ')) 
                                    
                if similarity_score >= 0.4:
                    aspect_dict[aspect].append(ngram)
                    
                #some values need to be hard coded in since word2vec
                #does not recognize ssd or solid state as well
                if aspect == 'hard drive':
                    if 'solid' in ngram:
                        if 'state' in ngram:
                            aspect_dict[aspect].append(ngram)

                    if 'ssd' in ngram:
                        aspect_dict[aspect].append(ngram)
    
            except:
                continue

    return aspect_dict

# %%
unique_product_parents = sorted(helpful_df['product_parent'].unique())

errors = []
pros_and_cons_dict = defaultdict(dict)


#define stopwords
orig_stopwords = set(stopwords.words('english'))

laptop_brands = ['asus', 'acer', 'alienware', 'apple', 'dell', 'hp', 'lenovo', 'samsung']
laptop_types = ['laptop', 'chromebook', 'macbook']

orig_stopwords = orig_stopwords.union(set(laptop_brands))
orig_stopwords = orig_stopwords.union(set(laptop_types))

misc = ['wa', 'windows', 'mac', 'computer', 'window', 'star', 'comment', 
        'macs', 'hewlett', 'thing', 'review', 'rating', 'like', 'laptop', 
        'pc', 'chrome', 'book', 'bill', 'packard', 'netflix', 'gates', 
        'steve', 'job', 'microsoft', 'http', 'www', 'people', 'google', 
        'amazon', 'grammar', 'youtube', 'geek', 'squad', 'reviewer', 
        'read', 'guy', 'bird', 'lap', 'top', 'luck', 'gift', 'day', 'bar']

orig_stopwords = orig_stopwords.union(set(misc))


#define aspects
aspects = ['battery', 'ports', 'price', 'hard drive', 'processor speed', 'screen', 
           'ergonomic', 'fan cooling', 'sound', 'build quality', 'ram']


for idx, product_parent in enumerate(unique_product_parents):    
    try:
        product_parent_mask = helpful_df['product_parent'] == product_parent

        title = helpful_df.loc[product_parent_mask, 'product_title'].values[0]

        brand = title.split(' ')[0]

        #find the pros and cons for a product parent
        pros, cons = pros_and_cons(helpful_df, product_parent, orig_stopwords)

        #find how pros and cons are related to our defined aspects
        pro_aspects = aspect_generator(aspects, pros)
        con_aspects = aspect_generator(aspects, cons)

        positive_sentences = helpful_df.loc[product_parent_mask, 'positive_sentences'].values #list of lists
        positive_sentences = [item for sublist in positive_sentences for item in sublist] #flatten into one list 

        negative_sentences = helpful_df.loc[product_parent_mask, 'negative_sentences'].values
        negative_sentences = [item for sublist in negative_sentences for item in sublist]

        lemmatized_positives = helpful_df.loc[product_parent_mask, 'lemmatized_positives'].values
        lemmatized_positives = [item for sublist in lemmatized_positives for item in sublist]

        lemmatized_negatives = helpful_df.loc[product_parent_mask, 'lemmatized_negatives'].values
        lemmatized_negatives = [item for sublist in lemmatized_negatives for item in sublist]


        pros_and_cons_dict[brand][product_parent] = {'product_title': title,
                                                     'pros': pros, 
                                                     'cons': cons, 
                                                     'pro_aspects': pro_aspects, 
                                                     'con_aspects': con_aspects,
                                                     'positive_sentences': positive_sentences,
                                                     'negative_sentences': negative_sentences,
                                                     'lemmatized_positives': lemmatized_positives,
                                                     'lemmatized_negatives': lemmatized_negatives}

    except:
        errors.append(idx)
        
    print(idx, title)
# Out:
# 0 Apple MacBook Pro 13.3-Inch
# 1 Acer 13 Chromebook 13.3-inch Full HD
# 2 Samsung 11-Inch Chromebook 2 11.6-Inch Cloud Computer
# 3 Dell Inspiron 15 5000 Series 15-Inch Touchscreen Laptop Silver
# 4 ASUS T100 10-Inch Laptop OLD VERSION
# 5 HP Pavilion G6-2235us 15.6" Laptop (2.7 GHz AMD A6-4400M Accelerated Processor, 4GB RAM, 750GB Hard Drive, SuperMulti DVD Burner, Windows 8)
# 6 ASUS N550J 15.6-Inch Laptop (Intel Core i7-4700HQ 2.4GHz Processor, 1TB Hard Drive, 8GB RAM, Windows 8.1 64-bit) Silver Grey
# 7 Samsung ATIV Book 6 15.6-Inch Full HD Touchscreen Laptop (Mineral Ash Black)
# 8 Apple 13-Inch MacBook T7200 2.0 GHz Intel Core 2 Duo Processor, White
# 9 Apple MacBook MA472LL/A 13.3" Laptop (2.0 GHz Intel Core Duo, 512 MB RAM, 80 GB Hard Drive, SuperDrive)-Black
# 10 Acer C720 Chromebook (11.6-Inch, 4GB)
# 11 Acer Aspire AS5251-1805 15.6-Inch Laptop (Black)
# 12 Acer C720 Chromebook (11.6-Inch, 2GB) Discontinued by Manufacturer
# 13 ASUS K501UX 15-inch Gaming Laptop (Intel Core i7 Processor, 8GB RAM, 256GB SSD Hard Drive, Windows 10 (64 bit)), Black/Silver Metal
# 14 Acer Aspire One 8.9" Mini Laptop
# 15 Apple MacBook MA254LL/A 13.3" Laptop (1.83 GHz Intel Core Duo, 512 MB RAM, 60 GB Hard Drive, DVD-ROM/CD-RW Drive)- White
# 16 Samsung Series 5 550 Chromebook
# 17 Apple MacBook Pro 13" 2.26GHz (MB990LL/A), 8GB Memory, 500GB Solid State Hybrid Drive
# 18 Acer Aspire V5-571P-6642 15.6-Inch Touch Screen Laptop (1.7 GHz Intel Core i5-3317U Processor, 6GB DDR3, 500GB HDD, Windows 8) Silky Silver
# 19 HP Envy 17-j130us 17.3-Inch Touchsmart Laptop with Beats Audio
# 20 Acer C720P Chromebook
# 21 Dell D600 Laptop (1.6ghz, 40 GB Hard Drive, DVD/CD-RW)
# 22 Apple iBook Laptop 14.1" M9848LL/A (1.42 GHz PowerPC G4, 512 MB DDR SDRAM, 60 GB Hard Drive, SuperDrive)
# 23 Apple MacBook Air
# 24 HP Chromebook 14
# 25 HP g7-1310us (17.3-Inch Screen) Laptop
# 26 Apple MacBook MA255LL/A 13.3" Laptop (2.0 GHz Intel Core Duo, 512 MB RAM, 60 GB Hard Drive, SuperDrive)- White
# 27 ASUS Flip 15.6 inches 2-in-1 Core i3 Touchscreen Laptop
# 28 Lenovo Thinkpad E545 20B20011US 15.6-Inch Laptop
# 29 ASUS X200 11-Inch Laptop [OLD VERSION]
# 30 ASUS ROG G750JM 17-Inch Gaming Laptop [OLD VERSION]
# 31 HP Pavilion DV7-1200US Series 17.0-Inch Laptop
# 32 Apple MacBook Pro ME865LL/A 13.3-Inch Laptop with Retina Display (OLD VERSION)
# 33 Apple MacBook Pro 15.4-Inch Laptop
# 34 Lenovo B590 Windows 7 Pentium 15.6-Inch Laptop (Black) 59410452
# 35 ASUS X551 15.6-inch Laptop (Intel Celeron 2.16GHz Processor, 4GB RAM, 500GB HDD, Windows 8.1 includes Windows 10 upgrade), Black
# 36 Acer C7 C710-2847 Chromebook 11.6" Intel Dual Core B847 1.1 GHz 2GB DDR3 320GB 5400RPM HDD Wifi HDMI USB3.0 VGA Card Reader
# 37 ASUS N550 15-Inch Laptop [OLD VERSION]
# 38 Dell Inspiron 11 i3147 – 3750slv 11.6" 2-In-1 Convertible Laptop - Intel Pentium Quad-Core N3530 Processor 2.16Ghz - 4GB 500GB - Touch Screen - Win 8.1 [Discontinued By Manufacturer]
# 39 Apple MacBook Air
# 40 ASUS X205 11.6 Inch Laptop [OLD VERSION]
# 41 HP Chromebook 14 - New Version Snow White
# 42 ASUS Chromebook 11.6"
# 43 Acer Aspire 17.3-Inch Laptop Intel Core, 4GB RAM, 500GB HDD, Windows 7 Home Premium 64 bits
# 44 Apple MacBook 13.3-inch Laptop
# 45 ASUS Chromebook C200MA-DS01 11.6-Inch Laptop
# 46 Apple MacBook MA700LL/A 13.3" Laptop (2.0 GHz Intel Core 2 Duo, 1 GB RAM, 80 GB Hard Drive, SuperDrive) - White
# 47 Samsung Chromebook 2 13.3 Inch  Laptop (Samsung Exynos, 4 GB, 16 GB SSD, Luminous Titan)
# 48 Apple MacBook Air 11.6-Inch Laptop
# 49 Apple MacBook 13.3-Inch Laptop
# 50 HP 2000-2b19wm 15.6-Inch Laptop PC (Winter Blue)
# 51 Apple MacBook Pro with Retina Display
# 52 HP Envy 11-g010nr 11.6-Inch Detachable 2 in 1 Touchscreen Laptop
# 53 Acer Aspire E 11 ES1-111M-C40S 11.6-Inch Laptop (Diamond Black)
# 54 Samsung Chromebook (Wi-Fi, 11.6-Inch) 2012 Model
# 55 HP Pavilion G Series Laptop
# 56 ASUS N56 Full-HD 1080P 15.6-Inch Laptop
# 57 Samsung Chromebook 2 11.6-Inch Silver
# 58 HP 14-q070nr 14-Inch Chromebook (free T-Mobile 4G)
# 59 Acer Aspire 15.6-Inch Laptop (Diamond Black)
# 60 Dell Inspiron 15 i15RV-6190BLK 15.6-Inch Laptop (Black Matte with Textured Finish) [Discontinued By Manufacturer]
# 61 Apple MD231LL MacBook Air
# 62 Apple MacBook 12-Inch Laptop
# 63 Apple MacBook Pro ME293LL/A 15.4-Inch Laptop with Retina Display (OLD VERSION)
# 64 Apple MacBook 13.3-inch Laptop
# 65 Dell Inspiron i3542-5000BK 15.6-Inch Multi-Touch Laptop 4th Generation Intel Core i3-4030U Processor 4GB DDR3, 500GB Hard Drive Integrated Graphics Windows 8.1
# 66 Dell Latitude D610 Laptop CD-RW/ DVD Wireless Computer
# 67 ASUS X205TA 11.6 Inch Laptop Intel Atom, 2 GB, 32GB SSD
# 68 ASUS S400CA-DH51 14-Inch TouchScreen Laptop
# 69 ASUS X551MA 15.6 Inch Laptop (Intel Celeron, 4 GB, 500GB HDD, Black) - Free Upgrade to Windows 10
# 70 Apple MacBook Air MC960 Series
# 71 Apple PowerBook Laptop 15" M9422LL/A (1.50-GHz PowerPC G4, 512 MB RAM, 80 GB Hard Drive, SuperDrive)
# 72 Apple MacBook MA
# 73 ASUS UL30A-X5 Thin and Light 13.3-Inch Black Laptop (12 Hours of Battery Life)
# 74 Acer 15.6-Inch Laptop
# 75 Apple MacBook Pro Laptop with Retina Display
# 76 Apple MacBook Pro MGXX2LL/A
# 77 HP Stream 14 Laptop with Beats Audio (Natural Silver) (Discontinued by Manufacturer)
# 78 Apple MacBook Pro MC374LL/A 13.3-Inch Laptop (OLD VERSION)
# 79 ASUS UX303 13-Inch Laptop [2014 model]
# 80 Apple MacBook Pro
# 81 Dell Computer Inspiron 13 7000 Series 13-Inch Laptop Silver
# 82 Apple MacBook Pro  Laptop
# 83 ASUS Transformer Book 10.1 Inch 2 in1 Touch Laptop T100TA-H1-GR Grey 2Gb RAM, 32GB SSD, 500GB HDD, Win 8.1
# 84 HP Chromebook 11-1101 (White/Blue)
# 85 Apple iBook Laptop 12" M9623LL/A (1.2 GHz PowerPC G4, 256MB RAM, 30GB Hard Drive, Combo Drive, Built-in AirPort Extreme)
# 86 ASUS UX305 13-Inch Laptop [PREVIOUS GEN MODEL]
# 87 Acer Chromebook 15 CB5-571-C09S (15.6-Inch Full HD IPS, 4GB RAM,  SSD)
# 88 Apple MacBook Pro Laptop
# 89 Apple MacBook Pro MC700LL/A 13.3-Inch Laptop (OLD VERSION)
# 90 ASUS VivoBook X202E-DH31T 11.6-Inch Touch Laptop
# 91 HP ENVY 15t i7-4710HQ Quad Core Notebook Laptop PC
# 92 Apple MacBook MC207LL/A 13.3-Inch Laptop (OLD VERSION)
# 93 ASUS G73JW-A1 Republic of Gamers 17.3-Inch Gaming Laptop
# 94 ASUS UX31 13-Inch Laptop [2011 model]
# 95 ASUS ROG 15.6" Gaming Laptop w/ GeForce GTX860M 2GB GDDR5 and Optimus Technology
# 96 HP Pavilion X2 10.1-inch Detachable 2 in 1 Laptop 32GB
# 97 Dell 2016 Inspiron Flagship High Performance 15.6" HD Touchscreen Backlit Keyboard Laptop PC | AMD A10-8700P Quad-Core CPU| 8GB RAM| 1TB HDD| DVDRW| Windows 10 (Silver) | Woov Laptop Sleeve
# 98 Samsung Series 9 NP900X3A-A03US 13.3-Inch Laptop (1.4GHz Intel Core i5 Processor, 4GB DDR3, 128GB SSD, Windows 7 Home Premium) Black
# 99 Dell D620 Laptop Duo Core with Windows XP
# 100 HP Stream 11 Laptop Includes Office 365 Personal for One Year Orchid Magenta
# 101 ASUS T100 10-Inch Laptop [2014],(gray)
# 102 Apple iBook Laptop 12.1" M9164LL/A (800-MHz PowerPC G4, 256 MB RAM, 30 GB Hard Drive, DVD/CD-RW Drive)
# 103 ASUS Chromebook C300MA 13.3 Inch (Intel Celeron, 2 GB, 16GB SSD, Black)
# 104 Lenovo G50 15.6-Inch Laptop (Core i3, 6 GB, 500 GB)
# 105 Acer Aspire V5-122P 11.6-Inch Touchscreen Laptop (Chill Silver)
# 106 Apple MacBook Core 2 Duo T7200 2.0GHz 1GB 80GB CDRW/DVD 13.3" AirPort OS X w/Webcam
# 107 Dell Inspiron i3531-1200BK 16-Inch Laptop Intel Celeron Processor, Black
# 108 HP 15-p030nr 15.6-Inch Special Edition Laptop with Beats Audio (Red)
# 109 Acer AC700-1099 Chromebook (Wi-Fi)
# 110 Apple MacBook Air MC505LL/A 11.6-Inch Laptop (OLD VERSION)

# %%
rewrite = False

if rewrite:
    with gzip.open('./data/pros_and_cons_dict.pkl.gz', 'wb') as f:
        pickle.dump(pros_and_cons_dict, f)

else:
    if 'pros_and_cons_dict.pkl.gz' in os.listdir('data'):
        with gzip.open('./data/pros_and_cons_dict.pkl.gz', 'wb') as f:
            pros_and_cons_dict = pickle.load(pros_and_cons_dict, f)

# %% [markdown]
# Return to [Table of Contents](#table)
